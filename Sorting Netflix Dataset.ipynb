# %%
import pandas as pd           # importing pandas library

# %%
df = pd.read_csv("datasets/netflix_data.csv")                  # Fetching Netflix dataset
df         # displaying data
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.sort_values(by='country')
# Out:
#      show_id     type                          title  \
# 4495   s4496  TV Show              No Time for Shame
# 3805   s3806    Movie  Luciano Mellera: Infantiloide
# 4870   s4871    Movie             Pizza, birra, faso
# 2749   s2750  TV Show            Historia de un clan
# 5685   s5686    Movie           So Much Love to Give
# ...      ...      ...                            ...
# 7739   s7740    Movie                Your Excellency
# 7746   s7747  TV Show                   دفعة القاهرة
# 7765   s7766    Movie                      Zero Hour
# 7777   s7778  TV Show                    Zombie Dumb
# 7784   s7785    Movie              Zulu Man in Japan
#
#                                    director  \
# 4495                                    NaN
# 3805                 Raúl Campos, Jan Suter
# 4870  Israel Adrián Caetano, Bruno Stagnaro
# 2749                                    NaN
# 5685                       Marcos Carnevale
# ...                                     ...
# ...

# %%
df.sort_values(by='country', ascending=False)
# Out:
#      show_id     type                title  \
# 1493   s1494    Movie             Cook Off
# 2757   s2758    Movie    Hitler - A Career
# 5654   s5655    Movie  Sky Tour: The Movie
# 939     s940    Movie        Bitcoin Heist
# 1482   s1483    Movie     Conjuring Spirit
# ...      ...      ...                  ...
# 7739   s7740    Movie      Your Excellency
# 7746   s7747  TV Show         دفعة القاهرة
# 7765   s7766    Movie            Zero Hour
# 7777   s7778  TV Show          Zombie Dumb
# 7784   s7785    Movie    Zulu Man in Japan
#
#                                    director  \
# 1493                        Tomas Brickhill
# 2757  Joachim Fest, Christian Herrendoerfer
# 5654                      Nguyen Thanh Tung
# 939                                Ham Tran
# 1482                            Van M. Pham
# ...                                     ...
# 7739                         Funke Akindele
# 7746                                    NaN
# ...

# %%
df.sort_values(by=['country', 'title']) # sorting multiple values
# Out:
#      show_id     type                                          title  \
# 92       s93    Movie                    27, el club de los malditos
# 194     s195    Movie  A Life of Speed: The Juan Manuel Fangio Story
# 230     s231    Movie                               A Sort of Family
# 291     s292    Movie                                       Abzurdah
# 344     s345    Movie                    Agustín Aristarán: Soy Rada
# ...      ...      ...                                            ...
# 7784   s7785    Movie                              Zulu Man in Japan
# 7746   s7747  TV Show                                   دفعة القاهرة
# 38       s39  TV Show                            แผนร้ายนายเจ้าเล่ห์
# 2082   s2083  TV Show                                           海的儿子
# 3089   s3090    Movie                            최강전사 미니특공대 : 영웅의 탄생
#
#              director                                               cast  \
# ...

# %%
df.sort_values(by=['country', 'title'], ascending=[True, False])
# Out:
#      show_id     type                                              title  \
# 7417   s7418  TV Show                                    Vientos de agua
# 7343   s7344    Movie                                          Underdogs
# 7126   s7127    Movie                  Todo lo que sería Lucas Lauriente
# 7127   s7128    Movie                                Todo Sobre El Asado
# 6921   s6922    Movie                                      The Tenth Man
# ...      ...      ...                                                ...
# 178     s179    Movie                    A Go! Go! Cory Carson Halloween
# 141     s142  TV Show                                             7SEEDS
# 117     s118    Movie                                     5 Cowok Jagoan
# 97       s98    Movie                                        3 Deewarein
# 67       s68    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
#
#                          director  \
# 7417                          NaN
# ...

# %%
df.sort_values(by=['country', 'title'], ascending=[True, False], inplace=True)
df
# Out:
#      show_id     type                                              title  \
# 7417   s7418  TV Show                                    Vientos de agua
# 7343   s7344    Movie                                          Underdogs
# 7126   s7127    Movie                  Todo lo que sería Lucas Lauriente
# 7127   s7128    Movie                                Todo Sobre El Asado
# 6921   s6922    Movie                                      The Tenth Man
# ...      ...      ...                                                ...
# 178     s179    Movie                    A Go! Go! Cory Carson Halloween
# 141     s142  TV Show                                             7SEEDS
# 117     s118    Movie                                     5 Cowok Jagoan
# 97       s98    Movie                                        3 Deewarein
# 67       s68    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
#
#                          director  \
# 7417                          NaN
# ...

# %%
df.sort_index()        # setting it back to earlier position
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df['country'].sort_values()
# Out:
# 7417    Argentina
# 3250    Argentina
# 3043    Argentina
# 3035    Argentina
# 2884    Argentina
#           ...
# 178           NaN
# 141           NaN
# 117           NaN
# 97            NaN
# 67            NaN
# Name: country, Length: 7787, dtype: object
